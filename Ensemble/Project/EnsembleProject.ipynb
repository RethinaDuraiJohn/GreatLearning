# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# **Data Understanding & Exploration: [5 Marks]**
#
# A. Read ‘TelcomCustomer-Churn_1.csv’ as a DataFrame and assign it to a variable. [1 Mark]
#
# B. Read ‘TelcomCustomer-Churn_2.csv’ as a DataFrame and assign it to a variable. [1 Mark]
#
# C. Merge both the DataFrames on key ‘customerID’ to form a single DataFrame [2 Mark]
#
# D. Verify if all the columns are incorporated in the merged DataFrame by using simple comparison Operator in Python. [1 Marks]

# %% [markdown]
# **1 a. Read ‘TelcomCustomer-Churn_1.csv’ as a DataFrame
# and assign it to a variable**

# %%
data1 = pd.read_csv("/workspaces/GreatLearning/Ensemble/Project/TelcomCustomer-Churn_1.csv")

# %% [markdown]
# **1 b.Read ‘TelcomCustomer-Churn_2.csv’ as a DataFrame
# and assign it to a variable**

# %%
data2 = pd.read_csv("/workspaces/GreatLearning/Ensemble/Project/TelcomCustomer-Churn_2.csv")

# %% [markdown]
# **1 c.Merge both the DataFrames on key ‘customerID’ to form
# a single DataFrame**

# %%
data1.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity
# 0  No phone service             DSL             No
# 1                No             DSL            Yes
# 2                No             DSL            Yes
# 3  No phone service             DSL            Yes
# 4                No     Fiber optic             No

# %%
data2.head()
# Out:
#    customerID OnlineBackup DeviceProtection TechSupport StreamingTV  \
# 0  7590-VHVEG          Yes               No          No          No
# 1  5575-GNVDE           No              Yes          No          No
# 2  3668-QPYBK          Yes               No          No          No
# 3  7795-CFOCW           No              Yes         Yes          No
# 4  9237-HQITU           No               No          No          No
#
#   StreamingMovies        Contract PaperlessBilling              PaymentMethod  \
# 0              No  Month-to-month              Yes           Electronic check
# 1              No        One year               No               Mailed check
# 2              No  Month-to-month              Yes               Mailed check
# 3              No        One year               No  Bank transfer (automatic)
# 4              No  Month-to-month              Yes           Electronic check
#
#    MonthlyCharges TotalCharges Churn
# 0           29.85        29.85    No
# ...

# %%
data = pd.merge(data1, data2, on='customerID')

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# **1 d.Verify if all the columns are incorporated in the merged
# DataFrame by using simple comparisonOperator in Python**

# %%
data1_col = data1.columns
data2_col = data.columns
data_col = data.columns

# %%
#data1 columns plus data2 columns
cols =  set(data1_col.append(data2_col))

# %%
#merged columns
data_col = set(data_col)

# %%
#comparining all columns from data1 and data2 are incorporated in merged dataframe
cols == data_col
# Out:
# True

# %% [markdown]
# Compared both , all columns from two df are incorporated in merged df

# %% [markdown]
# **2 a Impute missing/unexpected values in the DataFrame**

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
data.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
for i in data.columns:
    print(i)
    print(data[i].unique())
    print()
# Out:
# customerID
# ['7590-VHVEG' '5575-GNVDE' '3668-QPYBK' ... '4801-JZAZL' '8361-LTMKD'
#  '3186-AJIEK']
#
# gender
# ['Female' 'Male']
#
# SeniorCitizen
# [0 1]
#
# Partner
# ['Yes' 'No']
#
# Dependents
# ['No' 'Yes']
#
# tenure
# [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26  0
#  39]
#
# PhoneService
# ['No' 'Yes']
#
# MultipleLines
# ['No phone service' 'No' 'Yes']
#
# InternetService
# ['DSL' 'Fiber optic' 'No']
#
# OnlineSecurity
# ['No' 'Yes' 'No internet service']
#
# OnlineBackup
# ['Yes' 'No' 'No internet service']
#
# DeviceProtection
# ['No' 'Yes' 'No internet service']
#
# TechSupport
# ['No' 'Yes' 'No internet service']
#
# StreamingTV
# ['No' 'Yes' 'No internet service']
#
# StreamingMovies
# ['No' 'Yes' 'No internet service']
#
# Contract
# ['Month-to-month' 'One year' 'Two year']
#
# PaperlessBilling
# ...

# %%
sorted(data["TotalCharges"].unique())
# Out:
# [' ',
#  '100.2',
#  '100.25',
#  '100.35',
#  '100.4',
#  '100.8',
#  '100.9',
#  '1001.2',
#  '1001.5',
#  '1003.05',
#  '1004.35',
#  '1004.5',
#  '1004.75',
#  '1005.7',
#  '1006.9',
#  '1007.8',
#  '1007.9',
#  '1008.55',
#  '1008.7',
#  '1009.25',
#  '101.1',
#  '101.45',
#  '101.65',
#  '101.9',
#  '1010',
#  '1011.05',
#  '1011.5',
#  '1011.8',
#  '1012.4',
#  '1013.05',
#  '1013.2',
#  '1013.35',
#  '1013.6',
#  '1014.25',
#  '1016.7',
#  '1017.35',
#  '102.45',
#  '102.5',
#  '102.75',
#  '1020.2',
#  '1020.75',
#  '1021.55',
#  '1021.75',
#  '1021.8',
#  '1022.5',
#  '1022.6',
#  '1022.95',
#  '1023.75',
#  '1023.85',
#  '1023.9',
#  '1023.95',
#  '1024',
#  '1024.65',
#  '1024.7',
#  '1025.05',
#  '1025.15',
#  '1025.95',
#  '1026.35',
#  '1027.25',
#  '1028.75',
#  '1028.9',
#  '1029.35',
#  '1029.75',
#  '1029.8',
#  '103.7',
#  '1031.1',
#  '1031.4',
#  '1031.7',
#  '1032',
#  '1032.05',
#  '1033',
#  '1033.9',
#  '1033.95',
#  '1035.5',
#  '1035.7',
#  '1036',
# ...

# %%
numeric_values = pd.to_numeric(data['TotalCharges'], errors='coerce').dropna()
median_value = np.median(numeric_values)
data['TotalCharges'] = pd.to_numeric(data['TotalCharges'], errors='coerce').fillna(median_value)

# %%
sorted(data["TotalCharges"].unique())
# Out:
# [18.8,
#  18.85,
#  18.9,
#  19.0,
#  19.05,
#  19.1,
#  19.15,
#  19.2,
#  19.25,
#  19.3,
#  19.4,
#  19.45,
#  19.5,
#  19.55,
#  19.6,
#  19.65,
#  19.7,
#  19.75,
#  19.8,
#  19.85,
#  19.9,
#  19.95,
#  20.0,
#  20.05,
#  20.1,
#  20.15,
#  20.2,
#  20.25,
#  20.3,
#  20.35,
#  20.4,
#  20.45,
#  20.5,
#  20.55,
#  20.6,
#  20.65,
#  20.7,
#  20.75,
#  20.8,
#  20.85,
#  20.9,
#  20.95,
#  21.0,
#  21.05,
#  21.1,
#  23.45,
#  24.0,
#  24.05,
#  24.2,
#  24.25,
#  24.4,
#  24.45,
#  24.6,
#  24.7,
#  24.75,
#  24.8,
#  24.9,
#  25.0,
#  25.05,
#  25.1,
#  25.15,
#  25.2,
#  25.25,
#  25.3,
#  25.35,
#  25.4,
#  25.7,
#  25.75,
#  25.8,
#  25.85,
#  27.55,
#  28.3,
#  29.15,
#  29.7,
#  29.85,
#  29.9,
#  29.95,
#  30.2,
#  30.5,
#  30.55,
#  31.2,
#  31.35,
#  31.55,
#  31.9,
#  32.7,
#  33.2,
#  33.6,
#  33.7,
#  34.7,
#  34.75,
#  34.8,
#  35.0,
#  35.05,
#  35.1,
#  35.25,
#  35.45,
#  35.55,
#  35.75,
#  35.85,
#  35.9,
#  36.45,
#  36.55,
#  36.8,
#  37.2,
#  38.0,
# ...

# %% [markdown]
# 'Total Charges' column is cleaned

# %% [markdown]
# **2 B. Make sure all the variables with continuous values are of ‘Float’ type. [2 Marks]
# [For Example: MonthlyCharges, TotalCharges]**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
data["SeniorCitizen"] = data["SeniorCitizen"].astype(object)

# %% [markdown]
# **All continuous variables of float type already cleaned Total Charges in previous step**

# %% [markdown]
# **2 c Create a function that will accept a DataFrame as input
# and return pie-charts for all theappropriate Categorical
# features. Clearly show percentage distribution in the
# pie-chart.**

# %%
def distribution_pie_charts(data):

    categorical_columns = data.select_dtypes(include=['object']).columns
    for column in categorical_columns:
        values = data[column].value_counts()
        labels = values.index
        percentages = (values / values.sum()) * 100

        plt.figure(figsize=(4, 4))
        plt.pie(percentages, labels=labels, autopct='%1.1f%%', startangle=90)
        plt.title(f'Distribution Pie Chart for {column}')
        plt.show()

# %%
distribution_pie_charts(data)

# %% [markdown]
# **2 d.Share insights for Q2.c**

# %% [markdown]
# Lets see the distribution each pie-chart one by one
#
# **1.CustomerID**
# - this has so much categories , we are not able to find the distribution properly
#
# **2.gender**
# - male has 50.5% of data where as  Female has 49.5 % of data
# - the data distrubution is near to 50:50 (uniform)
#
# **3.SeniorCitizen**
# - 0 has 83.8 % of data and 1 has 16.2 of data
# - the data distribution is 8.3 : 1.6 for 0 : 1
#
# **4.Partner**
# -No has 51.7% of data and yes has 48.3% of data
# - the data distrubution is near to 50:50 (uniform)
#
# **5.Dependents**
# - No has 70% of data and yes has 30% of data
# - No has more data compared to yes
# - The distribution - 7:3 for No:Yes
#
# **6.Phone Service**
# - Yes has 90.3% of data and No has 9.7% of data
# - Yes has more data compared to No
# - The distribution - 9 : 0.97 for Yes:No
#
# **7.MultipleLines**
# - No has 48.1%of data , Yes has 42.2% of data and No phone service has 9.7% of data
# - the size order No > Yes > No phone service
# - The data distribution i  4:4:0.9 is No:yes:No Phone service
#
# **8.InternetService**
# - fiber optic has 44% of data , DSL has 34.4 % of data and No has 21.7% of data
# - The size order fiber optic > DSL > No
# - The data distribution - 4:3:2 for Fiber optic : DSL : No
#
# **9.OnlineSecurity**
# - No has 49.6% of data, yes has 28.7% of data and No internet service has 21.7% of data
# - The size order No > yes > No internet service
# - the data distribution - 4.9 : 2.8 : 2.1 for No : yes : No internet service
#
# **10.OnlineBackup**
# - No has 43.8% of data, yes has 34.5 % of data and No internet service has 21.7% of data
# - The size order No > Yes > no internet service
# - the data distribution - 4.3 : 3.4 : 2.1 for No : Yes : No internet service
#
# **11.DeviceProtection**
# - No has 43.9% of data, yes has 34.4% of data and No internet service has 21.7% of data
# - The size order No>yes>No internet service
#
# **12.TechSupport**
# - No has 49.3% of data, Yes has 29% and No internet service 21.7% of data
# - The size order No>yes>No internet service
# - The data distribution - 4.9 : 2.9 : 2.1  for No : Yes : No internet service
#
# **13.StreamingTV**
# - No has 39.9% of data, yes has 38.4 % and No internet service has 21.7%
# - The size order No > yes > No internet service
# - The data distribution - 3.9 : 3.8 : 2.1 for No : yes : No internet service
#
# **14.StreamingMovies**
# - No has 39.55 of data, Yes has 38.8% of data and No internet service has 21.7% of data
# - The size order No > Yes > No internet service
# - The data distribution - 3.9 : 3.8 : 2.1 for No L yes : No internet service
#
# **15.Contract**
# - Month-to-month has 55% of data, Two year has 24.1% of data and One year has 20.9% of data
# - The size order Month-to-month > two year > One year
# - The data distribution - 5.5 : 2.4 : 2 for Month-to-month : Two year : One year
#
# **16.Paperlessbiling**
# - yes has 59.2% of data and no has 40.8% of data
# - the size order Yes > No
# - the data distribution - 6 : 4 for Yes : No
#
# **17.PaymentMenthod**
# - Electronic check has 33.6% of data, Mailed check has 22.9% of data, bank transfer has 21.9% of data and credit card has 21.6% of data
# - The size order - electronic check > mailed check > Bank transfer > Credit card
# - The data distribution - 3:2:2:2 for electronic check : Mailed check : Bank transfer : Credit card
#
# **18.Churn**
# - No has 73.5% of data and Yes has 26.5% of data
# - The size order No > yes
# - The data distribution - 7.3 : 2.6 for No : yes

# %% [markdown]
# **2 e.Encode all the appropriate Categorical features with the
# best suitable approach**

# %%
#removing a CustomerID columns since its not useful
data = data.drop("customerID",axis=1)

# %%
categorical_columns = data.select_dtypes(include=['object']).columns
categorical_columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService',
#        'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'Contract', 'PaperlessBilling', 'PaymentMethod', 'Churn'],
#       dtype='object')

# %%
data = pd.get_dummies(data, columns=categorical_columns, drop_first=True)

# %%
data.head()
# Out:
#    tenure  MonthlyCharges  TotalCharges  gender_Male  SeniorCitizen_1  \
# 0       1           29.85         29.85        False            False
# 1      34           56.95       1889.50         True            False
# 2       2           53.85        108.15         True            False
# 3      45           42.30       1840.75         True            False
# 4       2           70.70        151.65        False            False
#
#    Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 0         True           False             False
# 1        False           False              True
# 2        False           False              True
# 3        False           False             False
# 4        False           False              True
#
#    MultipleLines_No phone service  MultipleLines_Yes  ...  StreamingTV_Yes  \
# 0                            True              False  ...            False
# 1                           False              False  ...            False
# ...

# %% [markdown]
# Encoding for all categorical columns are completed

# %% [markdown]
# **2 f.Split the data into 80% train and 20% test.**

# %%
X = data.drop('Churn_Yes', axis=1)
y = data['Churn_Yes']

# %%
X.head()
# Out:
#    tenure  MonthlyCharges  TotalCharges  gender_Male  SeniorCitizen_1  \
# 0       1           29.85         29.85        False            False
# 1      34           56.95       1889.50         True            False
# 2       2           53.85        108.15         True            False
# 3      45           42.30       1840.75         True            False
# 4       2           70.70        151.65        False            False
#
#    Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 0         True           False             False
# 1        False           False              True
# 2        False           False              True
# 3        False           False             False
# 4        False           False              True
#
#    MultipleLines_No phone service  MultipleLines_Yes  ...  \
# 0                            True              False  ...
# 1                           False              False  ...
# 2                           False              False  ...
# ...

# %%
y.head()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# Name: Churn_Yes, dtype: bool

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,stratify=y, random_state=42)

# %% [markdown]
# **2 g.Normalize/Standardize the data with the best suitable
# approach**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 31 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   tenure                                 7043 non-null   int64
#  1   MonthlyCharges                         7043 non-null   float64
#  2   TotalCharges                           7043 non-null   float64
#  3   gender_Male                            7043 non-null   bool
#  4   SeniorCitizen_1                        7043 non-null   bool
#  5   Partner_Yes                            7043 non-null   bool
#  6   Dependents_Yes                         7043 non-null   bool
#  7   PhoneService_Yes                       7043 non-null   bool
#  8   MultipleLines_No phone service         7043 non-null   bool
#  9   MultipleLines_Yes                      7043 non-null   bool
#  10  InternetService_Fiber optic            7043 non-null   bool
# ...

# %%
numeric_columns = X.select_dtypes(include=['int64', 'float64']).columns
numeric_columns
# Out:
# Index(['tenure', 'MonthlyCharges', 'TotalCharges'], dtype='object')

# %%
scaler = StandardScaler()
X_train[numeric_columns] = scaler.fit_transform(X_train[numeric_columns])
X_test[numeric_columns] = scaler.fit_transform(X_test[numeric_columns])

# %%
X_train.head()
# Out:
#         tenure  MonthlyCharges  TotalCharges  gender_Male  SeniorCitizen_1  \
# 3738  0.102371       -0.521976     -0.263289         True            False
# 3151 -0.711743        0.337478     -0.504814         True            False
# 4860 -0.793155       -0.809013     -0.751213         True            False
# 3867 -0.263980        0.284384     -0.173699        False            False
# 3810 -1.281624       -0.676279     -0.990851         True            False
#
#       Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 3738        False           False             False
# 3151         True            True              True
# 4860         True            True             False
# 3867         True           False              True
# 3810         True            True              True
#
#       MultipleLines_No phone service  MultipleLines_Yes  ...  \
# 3738                            True              False  ...
# 3151                           False              False  ...
# ...

# %%
X_test
